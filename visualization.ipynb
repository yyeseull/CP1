# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family='AppleGothic')

# %% [markdown]
# # 2018년 2021년 여행비율 파이차트

# %%
travel_2018_2021=pd.read_csv("/Users/yeseulseo/cp1/project/eda/관광여행_현황_20220907223332.csv",encoding='cp949')
travel_2018_2021 = travel_2018_2021.drop(['특성별(1)','특성별(2)','2018','2018.3','2018.5','2021'], axis=1)
travel_2018_2021
# Out:
#      2018.1   2018.2  2018.4   2021.1   2021.2 2021.3
# 0   국내_당일여행  국내_숙박여행    해외여행  국내_당일여행  국내_숙박여행   해외여행
# 1    횟수 (회)   횟수 (회)  횟수 (회)   횟수 (회)   횟수 (회)     소계
# 2       3.6      1.3     0.4      4.3      2.1    0.0
# 3       3.8      1.4     0.4      4.6      2.3    0.0
# 4       2.8      1.0     0.4      3.1      1.3    0.0
# 5       5.4      2.4     0.5      4.4      3.2    0.0
# 6       4.7      1.9     0.6      6.2      2.1    0.0
# 7       4.1      1.4     0.6      4.4      1.8    0.0
# 8       2.8      1.0     0.4      3.2      1.4    0.0
# 9       2.3      0.6     0.2      3.4      1.0    0.0
# 10      2.6      0.9     0.4      2.4      1.5    0.0
# 11      4.4      1.8     0.5      4.2      2.1    0.0
# 12      3.1      1.1     0.4      3.5      1.5    0.0
# 13      3.2      1.4     0.4      3.4      1.5    0.0
# 14      2.9      0.9     0.3      3.4      1.4    0.0
# 15      3.4      1.6     0.4      3.4      2.2    0.0
# 16      3.3      1.3     0.5      5.0      1.6    0.0
# 17      4.2      1.6     0.4      3.6      2.0    0.0
# 18      5.5      2.5     0.6      6.0      3.1    0.0

# %%
travel_2018_2021.columns = ['2018_국내_당일여행', '2018_국내_숙박여행', '2018_해외여행', '2021_국내_당일여행','2021_국내_숙박여행', '2021_해외여행']
travel_2018_2021 = travel_2018_2021.loc[2:2]
travel_2018_2021.reset_index(drop=True, inplace=True)

# %%
travel_2018_2021
# Out:
#   2018_국내_당일여행 2018_국내_숙박여행 2018_해외여행 2021_국내_당일여행 2021_국내_숙박여행 2021_해외여행
# 0          3.6          1.3       0.4          4.3          2.1       0.0

# %%
travel_2018_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   2018_국내_당일여행  1 non-null      object
#  1   2018_국내_숙박여행  1 non-null      object
#  2   2018_해외여행     1 non-null      object
#  3   2021_국내_당일여행  1 non-null      object
#  4   2021_국내_숙박여행  1 non-null      object
#  5   2021_해외여행     1 non-null      object
# dtypes: object(6)
# memory usage: 176.0+ bytes

# %%
travel_2018_2021 = travel_2018_2021.astype('float')
travel_2018_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   2018_국내_당일여행  1 non-null      float64
#  1   2018_국내_숙박여행  1 non-null      float64
#  2   2018_해외여행     1 non-null      float64
#  3   2021_국내_당일여행  1 non-null      float64
#  4   2021_국내_숙박여행  1 non-null      float64
#  5   2021_해외여행     1 non-null      float64
# dtypes: float64(6)
# memory usage: 176.0 bytes

# %%
# 2018년
ratio1=[3.6, 1.3, 0.4]

column_list = list(travel_2018_2021.columns)
labels1 = column_list[0:3]

plt.pie(ratio1, labels=labels1, autopct='%.1f%%')
plt.show()

# %%
# 2021년
ratio2=[4.3, 2.1, 0.0]

column_list = list(travel_2018_2021.columns)
labels2 = column_list[3:]


plt.pie(ratio2, labels=labels2, autopct='%.1f%%')
plt.show()

# %% [markdown]
# ### 히스토그램으로

# %%
# 2018년
bar_travel={
    'travel' : ['국내당일여행','국내숙박여행','해외여행'],
    '2018' : ratio1,
    '2021' : ratio2

}
bar_travel = pd.DataFrame(bar_travel)
bar_travel
# Out:
#    travel  2018  2021
# 0  국내당일여행   3.6   4.3
# 1  국내숙박여행   1.3   2.1
# 2    해외여행   0.4   0.0

# %%
fig, ax = plt.subplots(figsize=(12,6))
bar_width = 0.25

index = np.arange(3)

b2018 = plt.bar(index, bar_travel['2018'], bar_width, alpha=0.4, color='red', label='2018년')
for rect in b2018:
    height = rect.get_height()
    plt.text(rect.get_x()+rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size=12)
b2021 = plt.bar(index+bar_width, bar_travel['2021'], bar_width, alpha=0.4, color='blue', label='2021년')
for rect in b2021:
    height = rect.get_height()
    plt.text(rect.get_x()+rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size=12)
plt.xticks(np.arange(bar_width, 3+bar_width, 1), bar_travel['travel'])

plt.legend()
plt.show()

# %% [markdown]
# # 여행 안한 이유

# %%
df4=pd.read_csv('/Users/yeseulseo/cp1/project/eda/여행을_다녀오지_않은_이유__1순위__20220907223058.csv',encoding='cp949')
df4
# Out:
#    통계분류(1)         2018          2018.1    2018.2   2018.3       2018.4  \
# 0  통계분류(1)  여행에 관심이 없어서  여행이 재미없을 것 같아서  건강상의 문제로  시간이 없어서  여행 경비가 부족해서
# 1       전체          3.8             1.6       5.4     47.8          6.6
#
#         2018.5      2018.6          2018.7               2018.8  ...  \
# 0  여행 정보가 부족해서  관광시설이 불편해서  함께 여행할 사람이 없어서  가족 친구와 시간을 맞추기 힘들어서  ...
# 1          2.8         1.3             8.4                 19.5  ...
#
#      2021.2   2021.3       2021.4       2021.5      2021.6          2021.7  \
# 0  건강상의 문제로  시간이 없어서  여행 경비가 부족해서  여행 정보가 부족해서  관광시설이 불편해서  함께 여행할 사람이 없어서
# 1       6.4     26.2          3.4          1.8         1.7             4.4
#
#                 2021.8              2021.9 2021.10    2021.11
# 0  가족 친구와 시간을 맞추기 힘들어서  집안에 돌봐야 하는 가족이 있어서      기타  코로나19 때문에
# 1                 21.2                 1.4     0.4       26.9
#
# [2 rows x 47 columns]

# %%
df4.T
# Out:
#                            0     1
# 통계분류(1)              통계분류(1)    전체
# 2018             여행에 관심이 없어서   3.8
# 2018.1        여행이 재미없을 것 같아서   1.6
# 2018.2              건강상의 문제로   5.4
# 2018.3               시간이 없어서  47.8
# 2018.4           여행 경비가 부족해서   6.6
# 2018.5           여행 정보가 부족해서   2.8
# 2018.6            관광시설이 불편해서   1.3
# 2018.7        함께 여행할 사람이 없어서   8.4
# 2018.8   가족 친구와 시간을 맞추기 힘들어서  19.5
# 2018.9    집안에 돌봐야 하는 가족이 있어서   1.9
# 2018.10                   기타   0.8
# 2019             여행에 관심이 없어서   4.4
# 2019.1        여행이 재미없을 것 같아서   1.3
# 2019.2              건강상의 문제로    11
# 2019.3               시간이 없어서  50.5
# 2019.4           여행 경비가 부족해서     6
# 2019.5           여행 정보가 부족해서   1.6
# 2019.6            관광시설이 불편해서   0.5
# 2019.7        함께 여행할 사람이 없어서   4.7
# 2019.8   가족 친구와 시간을 맞추기 힘들어서  16.8
# 2019.9    집안에 돌봐야 하는 가족이 있어서   2.2
# 2019.10                   기타   0.8
# 2020             여행에 관심이 없어서   4.2
# 2020.1        여행이 재미없을 것 같아서   1.5
# 2020.2              건강상의 문제로   7.1
# 2020.3               시간이 없어서    26
# 2020.4           여행 경비가 부족해서   3.5
# 2020.5           여행 정보가 부족해서   1.6
# 2020.6            관광시설이 불편해서     1
# 2020.7        함께 여행할 사람이 없어서   3.9
# 2020.8   가족 친구와 시간을 맞추기 힘들어서    17
# 2020.9    집안에 돌봐야 하는 가족이 있어서   1.2
# 2020.10                   기타   0.4
# 2020.11            코로나19 때문에  32.5
# 2021             여행에 관심이 없어서   4.6
# 2021.1        여행이 재미없을 것 같아서   1.6
# 2021.2              건강상의 문제로   6.4
# 2021.3               시간이 없어서  26.2
# 2021.4           여행 경비가 부족해서   3.4
# 2021.5           여행 정보가 부족해서   1.8
# 2021.6            관광시설이 불편해서   1.7
# 2021.7        함께 여행할 사람이 없어서   4.4
# 2021.8   가족 친구와 시간을 맞추기 힘들어서  21.2
# 2021.9    집안에 돌봐야 하는 가족이 있어서   1.4
# 2021.10                   기타   0.4
# 2021.11            코로나19 때문에  26.9
